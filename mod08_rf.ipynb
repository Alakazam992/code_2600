# %%
# packages
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from sklearn.model_selection import train_test_split 
from sklearn.tree import \
      (DecisionTreeRegressor as DTR, 
       DecisionTreeClassifier as DTC, 
       plot_tree)
from sklearn.ensemble import \
     (RandomForestRegressor as RFR,
      RandomForestClassifier as RFC,
      GradientBoostingRegressor as GBR)
from sklearn.model_selection import cross_val_score

# set seed
seed = 5498

# %% [markdown]
# ### You'll need the heart attack data (heart.csv) to complete this exercise. Your goal is to predict the risk of having a heart attack (binary).

# %%
heart = pd.read_csv('data/heart.csv')
heart.head()
# Out:
#   Patient ID  Age   Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    UEX5427   40  Male          122         144/90         110         1
# 1    NBG3103   41  Male          357         174/73         109         0
# 2    EIE1041   58  Male          206        107/105          63         0
# 3    GYA0389   30  Male          142        132/107          86         1
# 4    IXT9616   69  Male          175         153/93          98         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        1  ...                 1.538008  252889
# 1               1        1        1  ...                 7.030873   63196
# 2               0        1        0  ...                 8.086554  107870
# 3               0        1        0  ...                 5.039048  223985
# 4               1        1        1  ...                 4.354972   24309
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# 0  28.854477            318                                6
# 1  37.387161             72                                7
# 2  20.299119            119                                2
# 3  30.717640            301                                5
# 4  19.115698            675                                7
#
#    Sleep Hours Per Day       Country      Continent           Hemisphere  \
# 0                    7      Thailand           Asia  Northern Hemisphere
# 1                    9        France         Europe  Northern Hemisphere
# 2                    5      Colombia  South America  Northern Hemisphere
# 3                    9  South Africa         Africa  Southern Hemisphere
# 4                    7         Japan           Asia  Northern Hemisphere
#
#    Heart Attack Risk
# 0                  1
# 1                  1
# 2                  0
# 3                  0
# 4                  0
#
# [5 rows x 26 columns]

# %%
heart.dtypes
# Out:
# Patient ID                             str
# Age                                  int64
# Sex                                    str
# Cholesterol                          int64
# Blood Pressure                         str
# Heart Rate                           int64
# Diabetes                             int64
# Family History                       int64
# Smoking                              int64
# Obesity                              int64
# Alcohol Consumption                  int64
# Exercise Hours Per Week            float64
# Diet                                   str
# Previous Heart Problems              int64
# Medication Use                       int64
# Stress Level                         int64
# Sedentary Hours Per Day            float64
# Income                               int64
# BMI                                float64
# Triglycerides                        int64
# Physical Activity Days Per Week      int64
# Sleep Hours Per Day                  int64
# Country                                str
# Continent                              str
# Hemisphere                             str
# Heart Attack Risk                    int64
# dtype: object

# %%
heart.shape
# Out:
# (6572, 26)

# %% [markdown]
# ### Feature engineering

# %%
def feature_engineering(df=heart):
    df['Male'] = (df.Sex == 'Male').astype(int)
    df['HealthyDiet'] = (df.Diet == 'Healthy').astype(int)
    df['UnhealthyDiet'] = (df.Diet == 'Unhealthy').astype(int)
    df[['BP1','BP2']] = df['Blood Pressure'].str.split('/', n=1, expand=True).astype(int)

feature_engineering()

# %%
heart.head()
# Out:
#   Patient ID  Age   Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    UEX5427   40  Male          122         144/90         110         1
# 1    NBG3103   41  Male          357         174/73         109         0
# 2    EIE1041   58  Male          206        107/105          63         0
# 3    GYA0389   30  Male          142        132/107          86         1
# 4    IXT9616   69  Male          175         153/93          98         1
#
#    Family History  Smoking  Obesity  ...  Sleep Hours Per Day       Country  \
# 0               0        1        1  ...                    7      Thailand
# 1               1        1        1  ...                    9        France
# 2               0        1        0  ...                    5      Colombia
# 3               0        1        0  ...                    9  South Africa
# 4               1        1        1  ...                    7         Japan
#
#        Continent           Hemisphere  Heart Attack Risk  Male  HealthyDiet  \
# 0           Asia  Northern Hemisphere                  1     1            0
# 1         Europe  Northern Hemisphere                  1     1            1
# 2  South America  Northern Hemisphere                  0     1            0
# 3         Africa  Southern Hemisphere                  0     1            0
# 4           Asia  Northern Hemisphere                  0     1            0
#
#    UnhealthyDiet  BP1  BP2
# 0              0  144   90
# 1              0  174   73
# 2              0  107  105
# 3              1  132  107
# 4              1  153   93
#
# [5 rows x 31 columns]

# %%
indep_vars = ['Age', 'Male', 'Cholesterol', 'BP1', 'BP2', 'Heart Rate', 'Diabetes', 
              'Family History', 'Smoking', 'Obesity', 'Alcohol Consumption', 'HealthyDiet', 
              'UnhealthyDiet', 'Exercise Hours Per Week', 'Previous Heart Problems', 
              'Medication Use', 'Stress Level', 'Sedentary Hours Per Day', 'Income', 'BMI',
              'Triglycerides', 'Physical Activity Days Per Week', 'Sleep Hours Per Day']

X = heart[indep_vars]
y = heart['Heart Attack Risk']

# %%
X_train, X_test, y_train, y_test, Train, Test = train_test_split(X, y, heart, 
                                                                 random_state = seed, 
                                                                 test_size = 0.33, 
                                                                 shuffle = True)

# %% [markdown]
# ### Univariate Analyses (Mean, Median, etc.)

# %%
Train.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  4403.000000  4403.000000  4403.000000  4403.000000     4403.000000
# mean     53.760164   261.571201    75.398592     0.656371        0.487168
# std      21.302684    81.111506    20.455754     0.474973        0.499892
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   194.000000    58.000000     0.000000        0.000000
# 50%      54.000000   261.000000    75.000000     1.000000        0.000000
# 75%      72.000000   333.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  4403.000000  4403.000000          4403.000000              4403.000000
# mean      0.895526     0.503066             0.599364                10.123129
# std       0.305909     0.500047             0.490083                 5.814093
# min       0.000000     0.000000             0.000000                 0.004443
# 25%       1.000000     0.000000             0.000000                 5.081525
# 50%       1.000000     1.000000             1.000000                10.266242
# 75%       1.000000     1.000000             1.000000                15.292125
# max       1.000000     1.000000             1.000000                19.998709
#
#        Previous Heart Problems  ...          BMI  Triglycerides  \
# count              4403.000000  ...  4403.000000    4403.000000
# mean                  0.506246  ...    28.876482     418.384738
# std                   0.500018  ...     6.266748     222.756253
# min                   0.000000  ...    18.009025      30.000000
# 25%                   0.000000  ...    23.397345     229.000000
# 50%                   1.000000  ...    28.768101     419.000000
# 75%                   1.000000  ...    34.269966     608.000000
# max                   1.000000  ...    39.997211     800.000000
#
#        Physical Activity Days Per Week  Sleep Hours Per Day  \
# count                      4403.000000          4403.000000
# mean                          3.470815             7.045651
# std                           2.289825             1.986313
# min                           0.000000             4.000000
# 25%                           1.000000             5.000000
# 50%                           3.000000             7.000000
# 75%                           5.000000             9.000000
# max                           7.000000            10.000000
#
#        Heart Attack Risk         Male  HealthyDiet  UnhealthyDiet  \
# count        4403.000000  4403.000000  4403.000000    4403.000000
# mean            0.363389     0.703157     0.336589       0.334999
# std             0.481030     0.456919     0.472597       0.472044
# min             0.000000     0.000000     0.000000       0.000000
# 25%             0.000000     0.000000     0.000000       0.000000
#T_31084_row12_col8, #T_31084_row12_col10, #T_31084_row12_col17, #T_31084_row12_col18, #T_31084_row12_col19, #T_31084_row13_col5, #T_31084_row13_col6, #T_31084_row13_col8, #T_31084_row13_col10, #T_31084_row14_col4, #T_31084_row14_col7, #T_31084_row14_col16, #T_31084_row14_col22, #T_31084_row15_col2, #T_31084_row15_col3, #T_31084_row15_col8, #T_31084_row15_col9, #T_31084_row15_col20, #T_31084_row16_col5, #T_31084_row16_col9, #T_31084_row16_col14, #T_31084_row17_col11, #T_31084_row17_col12, #T_31084_row17_col18, #T_31084_row17_col21, #T_31084_row17_col22, #T_31084_row18_col2, #T_31084_row18_col3, #T_31084_row18_col9, #T_31084_row18_col11, #T_31084_row18_col12, #T_31084_row18_col17, #T_31084_row18_col21, #T_31084_row19_col12, #T_31084_row19_col20, #T_31084_row19_col22, #T_31084_row20_col5, #T_31084_row20_col15, #T_31084_row20_col19, #T_31084_row21_col17, #T_31084_row21_col18, #T_31084_row22_col1, #T_31084_row22_col2, #T_31084_row22_col11, #T_31084_row22_col14, #T_31084_row22_col17, #T_31084_row22_col19 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_31084_row0_col6, #T_31084_row0_col22, #T_31084_row2_col4, #T_31084_row2_col9, #T_31084_row2_col10, #T_31084_row2_col14, #T_31084_row3_col7, #T_31084_row3_col14, #T_31084_row3_col21, #T_31084_row4_col2, #T_31084_row5_col7, #T_31084_row5_col11, #T_31084_row5_col12, #T_31084_row5_col19, #T_31084_row6_col0, #T_31084_row6_col7, #T_31084_row6_col19, #T_31084_row7_col3, #T_31084_row7_col5, #T_31084_row7_col6, #T_31084_row7_col13, #T_31084_row7_col20, #T_31084_row7_col22, #T_31084_row8_col14, #T_31084_row8_col16, #T_31084_row9_col2, #T_31084_row10_col2, #T_31084_row10_col17, #T_31084_row10_col18, #T_31084_row11_col5, #T_31084_row12_col5, #T_31084_row12_col14, #T_31084_row13_col7, #T_31084_row13_col18, #T_31084_row13_col21, #T_31084_row14_col2, #T_31084_row14_col3, #T_31084_row14_col8, #T_31084_row14_col12, #T_31084_row14_col18, #T_31084_row14_col20, #T_31084_row15_col18, #T_31084_row16_col8, #T_31084_row16_col22, #T_31084_row17_col10, #T_31084_row18_col10, #T_31084_row18_col13, #T_31084_row18_col14, #T_31084_row18_col15, #T_31084_row19_col5, #T_31084_row19_col6, #T_31084_row19_col21, #T_31084_row20_col7, #T_31084_row20_col14, #T_31084_row21_col3, #T_31084_row21_col13, #T_31084_row21_col19, #T_31084_row22_col0, #T_31084_row22_col7, #T_31084_row22_col16 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_31084_row0_col7, #T_31084_row1_col2, #T_31084_row2_col1, #T_31084_row2_col13, #T_31084_row3_col5, #T_31084_row3_col16, #T_31084_row3_col17, #T_31084_row3_col19, #T_31084_row4_col18, #T_31084_row5_col3, #T_31084_row5_col9, #T_31084_row5_col18, #T_31084_row5_col21, #T_31084_row5_col22, #T_31084_row6_col9, #T_31084_row7_col0, #T

# %% [markdown]
# ### To predict heart attack risk, we'll start by building a few simple decision trees.

# %%
tree1 = DTC(max_depth=1)
tree1.fit(X_train, y_train)

tree2 = DTC(max_depth=2)
tree2.fit(X_train, y_train)

tree3 = DTC(max_depth=3)
tree3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# ### We can draw plots of each of these decision trees

# %%
feature_names = list(X_train.columns)
ax = subplots(figsize=(6,6))[1]
plot_tree(tree1,
          feature_names=feature_names,
          ax=ax);

# %%
ax = subplots(figsize=(12,6))[1]
plot_tree(tree2,
          feature_names=feature_names,
          ax=ax);

# %%
ax = subplots(figsize=(18,8))[1]
plot_tree(tree3,
          feature_names=feature_names,
          ax=ax);

# %% [markdown]
# ### Create a new tree with depth 3 that requires there to be at least 100 records in each leaf.

# %%
tree4 = DTC(max_depth=4)
tree4.fit(X_train, y_train)

ax = subplots(figsize=(18,8))[1]
plot_tree(tree4,
          feature_names=feature_names,
          ax=ax);

# %% [markdown]
# ### Create a new version of the last tree so that it limits the number of leaf nodes to 8 rather than limiting the depth to 3.

# %%
tree5 = DTC(max_depth=5)
tree5.fit(X_train, y_train)

ax = subplots(figsize=(18,8))[1]
plot_tree(tree5,
          feature_names=feature_names,
          ax=ax);

# %% [markdown]
# ### Create a basic random forest model on the training set.

# %%
rf_basic = RFC(max_features=len(indep_vars),
               criterion='log_loss',
               n_estimators=50,
               max_depth=10,
               min_samples_leaf=1,
               bootstrap=True,
               oob_score=True,
               random_state=seed)
rf_basic.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=10, max_features=23,
#                        n_estimators=50, oob_score=True, random_state=5498)

# %% [markdown]
# ### We'll use this function to quickly calculate the log loss of a model.

# %%
def log_loss(y_true, y_prob, eps=1e-15):
    y_true = np.array(y_true)
    y_prob = np.array(y_prob)
    
    # avoid log(0)
    y_prob = np.clip(y_prob, eps, 1 - eps)
    
    ll = -np.mean(y_true * np.log(y_prob) + (1 - y_true) * np.log(1 - y_prob))
    return ll

# %% [markdown]
# ### Compute the log loss on the training set.

# %%
y_hat_basic_train = rf_basic.predict_proba(X_train)[:,1]
print('train log loss:', log_loss(y_train, y_hat_basic_train))
# Out:
# train log loss: 0.4682493561945568

# %% [markdown]
# ### Calculate the out-of-bag error (bootstrapping) on training data to estimate the log loss on the test set.

# %%
y_hat_basic_oob = rf_basic.oob_decision_function_[:,1]
print('oob log loss:  ', log_loss(y_train, y_hat_basic_oob))
# Out:
# oob log loss:   0.6662770624624337

# %% [markdown]
# ### Compute the log loss on the test set.

# %%
y_hat_basic_test = rf_basic.predict_proba(X_test)[:,1]
print('test log loss: ', log_loss(y_test, y_hat_basic_test))
# Out:
# test log loss:  0.65752143530385

# %% [markdown]
# ### Build an improved random forest model on this same set of data.
#
# You will be scored according to how well it performs on an unseen holdout set.

# %%
# Documentation: https://scikit-learn.org/dev/modules/generated/sklearn.ensemble.RandomForestRegressor.html

rf_better = #fillin

# %% [markdown]
# ### Calculate the out-of-bag log loss for this model. Store it as `log_loss_oob`

# %%
y_hat_better_oob = #fillin

log_loss_oob = #fillin
print(log_loss_oob)

# %% [markdown]
# ### Create the feature importance list for this model.

# %%
feature_imp = pd.DataFrame(
    {'importance':rf_better.feature_importances_},
    index=indep_vars)
feature_imp

# %% [markdown]
# ### Sort the importance values and then create a horizontal bar chart that displays the sorted variable importances.

# %%
feature_imp_sorted = #fillin

# Draw a horizontal bar chart
#fillin

# %% [markdown]
# ## Discussion Questions

# %% [markdown]
# ### (1) Explain what "value" means in the decision tree plots.

# %% [markdown]
# ### (2) How is “log loss” different from the log likelihood we defined in class?

# %% [markdown]
# ### (3) Explain how we know the basic model is overfit before attempting to build any other models.
